# %% [markdown]
# # Demo 0: KX2 & SCILA & Byonoy Routine

# %% [markdown]
# ## Import Statemets

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import asyncio
from tqdm.auto import tqdm

# %% [markdown]
# ## SCILA Incubator Setup
#
# 1. import modules you require
# 2. create a SCILA incubator backend, and give it the device's IP address
# 3. call `.setup()` to establish a connection and initialize the device
# 4.

# %%
from pylabrobot.storage.inheco.scila.soap import soap_encode, soap_decode, XSI
from pylabrobot.storage.inheco.scila.scila_backend import SCILABackend


scila = SCILABackend(scila_ip="169.254.1.117")

await scila.setup()

# %% [markdown]
# ### Status Requests

# %%
await scila.get_status()
# Out:
# 'idle'

# %%
await scila.get_drawer_positions()
# Out:
# {'Drawer1': 'Closed',
#  'Drawer2': 'Closed',
#  'Drawer3': 'Closed',
#  'Drawer4': 'Closed'}

# %%
drawer_indices = list(range(1, 5))

for idx in drawer_indices:
    
    temp_reponse = await scila.get_drawer_position(idx)

    print(idx, temp_reponse)
# Out:
# 1 Closed
# 2 Closed
# 3 Closed
# 4 Closed

# %% [markdown]
# ### Drawer Control
#
# Note: By firmware, only one drawer can be opened at a time!

# %%
for idx in tqdm(drawer_indices):
    
    await scila.open_drawer(idx)

    await asyncio.sleep(1) # wait for 1 second
    
    await scila.close_drawer(idx)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
await scila.open_drawer(1)
# Out:
# 2026-02-07 17:10:37,169 - pylabrobot.storage.inheco.scila.inheco_sila_interface - WARNING - No pending command to match response to.
# 2026-02-07 17:13:27,226 - pylabrobot.storage.inheco.scila.inheco_sila_interface - WARNING - No pending command to match response to.

# %% [markdown]
# ### Temperature Control

# %%
# Out:
# 21.01

# %%
await scila.set_tempeature(37.0)

# %%
for time_step in tqdm(range(10)):
    
    temperature_reading = await scila.get_current_temperature()

    print(temperature_reading)

    await asyncio.sleep(1)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 34.38
# 34.46
# 34.55
# 34.64
# 34.74
# 34.82
# 34.91
# 34.99
# 35.08
# 35.16

# %% [markdown]
# Uncomment the next coding cell if you want to stop temperature control:

# %%
# await scila.deactivate_temperature_control()

# %%
from pylabrobot.arms.kx2.kx2_backend import *

# %%
kx2 = KX2Backend()
can = kx2.can

# %%
x = await kx2.initialize()
x
# Out:
# motor send command 1 UI 4  False (1)
# motor send command 2 UI 4  False (1)
# motor send command 3 UI 4  False (1)
# motor send command 4 UI 4  False (1)
# motor send command 6 UI 4  False (1)
#
# axis 1
# motor send command 1 UI 5  False (1)
# motor send command 1 UI 6  False (1)
# motor send command 1 UI 7  False (1)
# motor send command 1 UI 8  False (1)
# motor send command 1 UI 9  False (1)
# motor send command 1 UI 10  False (1)
# motor send command 1 UI 11  False (1)
# motor send command 1 UI 12  False (1)
# motor send command 1 UI 13  False (1)
# motor send command 1 UI 14  False (1)
# motor send command 1 UI 15  False (1)
# motor send command 1 UI 16  False (1)
# motor send command 1 UI 24  False (1)
# motor send command 1 UF 1  True (2)
# motor send command 1 UF 2  True (2)
# motor send command 1 XM 1  False (1)
# motor send command 1 XM 2  False (1)
# motor send command 1 UF 3  True (2)
# motor send command 1 UF 4  True (2)
# motor send command 1 VH 3  False (1)
# motor send command 1 VL 3  False (1)
# motor send command 1 CA 45  False (1)
# motor send command 1 CA 41  False (1)
# motor send command 1 CA 46  False (1)
# motor send command 1 SP 2  False (1)
# motor send command 1 VH 2  False (1)
# motor send command 1 SD 0  False (1)
#
# axis 2
# motor send command 2 UI 5  False (1)
# motor send command 2 UI 6  False (1)
# motor send command 2 UI 7  False (1)
# motor send command 2 UI 8  False (1)
# motor send command 2 UI 9  False (1)
# motor send command 2 UI 10  False (1)
# motor send command 2 UI 11  False (1)
# motor send command 2 UI 12  False (1)
# motor send command 2 UI 13  False (1)
# motor send command 2 UI 14  False (1)
# motor send command 2 UI 15  False (1)
# motor send command 2 UI 16  False (1)
# motor send command 2 UI 24  False (1)
# motor send command 2 UF 1  True (2)
# motor send command 2 UF 2  True (2)
# motor send command 2 XM 1  False (1)
# motor send command 2 XM 2  False (1)
# motor send command 2 UF 3  True (2)
# motor send command 2 UF 4  True (2)
# motor send command 2 VH 3  False (1)
# motor send command 2 VL 3  False (1)
# motor send command 2 CA 45  False (1)
# motor send command 2 CA 41  False (1)
# motor send command 2 CA 46  False (1)
# motor send command 2 SP 2  False (1)
# motor send command 2 VH 2  False (1)
# motor send command 2 SD 0  False (1)
#
# axis 3
# motor send command 3 UI 5  False (1)
# motor send command 3 UI 6  False (1)
# motor send command 3 UI 7  False (1)
# motor send command 3 UI 8  False (1)
# motor send command 3 UI 9  False (1)
# motor send command 3 UI 10  False (1)
# motor send command 3 UI 11  False (1)
# motor send command 3 UI 12  False (1)
# motor send command 3 UI 13  False (1)
# motor send command 3 UI 14  False (1)
# motor send command 3 UI 15  False (1)
# motor send command 3 UI 16  False (1)
# motor send command 3 UI 24  False (1)
# motor send command 3 UF 1  True (2)
# motor send command 3 UF 2  True (2)
# motor send command 3 XM 1  False (1)
# motor send command 3 XM 2  False (1)
# motor send command 3 UF 3  True (2)
# motor send command 3 UF 4  True (2)
# motor send command 3 VH 3  False (1)
# motor send command 3 VL 3  False (1)
# motor send command 3 CA 45  False (1)
# motor send command 3 CA 41  False (1)
# motor send command 3 CA 46  False (1)
# motor send command 3 SP 2  False (1)
# motor send command 3 VH 2  False (1)
# motor send command 3 SD 0  False (1)
#
# axis 4
# motor send command 4 UI 5  False (1)
# motor send command 4 UI 6  False (1)
# motor send command 4 UI 7  False (1)
# motor send command 4 UI 8  False (1)
# motor send command 4 UI 9  False (1)
# motor send command 4 UI 10  False (1)
# motor send command 4 UI 11  False (1)
# motor send command 4 UI 12  False (1)
# motor send command 4 UI 13  False (1)
# motor send command 4 UI 14  False (1)
# motor send command 4 UI 15  False (1)
# motor send command 4 UI 16  False (1)
# motor send command 4 UI 24  False (1)
# motor send command 4 UF 1  True (2)
# motor send command 4 UF 2  True (2)
# motor send command 4 XM 1  False (1)
# motor send command 4 XM 2  False (1)
# motor send command 4 UF 3  True (2)
# motor send command 4 UF 4  True (2)
# motor send command 4 VH 3  False (1)
# motor send command 4 VL 3  False (1)
# motor send command 4 CA 45  False (1)
# motor send command 4 CA 42  False (1)
# motor send command 4 CA 46  False (1)
# motor send command 4 FF 3  True (2)
# motor send command 4 SP 2  False (1)
# motor send command 4 VH 2  False (1)
# motor send command 4 SD 0  False (1)
#
# axis 6
# motor send command 6 UI 5  False (1)
# motor send command 6 UI 6  False (1)
# motor send command 6 UI 7  False (1)
# motor send command 6 UI 8  False (1)
# motor send command 6 UI 9  False (1)
# motor send command 6 UI 10  False (1)
# motor send command 6 UI 11  False (1)
# motor send command 6 UI 12  False (1)
# motor send command 6 UI 13  False (1)
# motor send command 6 UI 14  False (1)
# motor send command 6 UI 15  False (1)
# motor send command 6 UI 16  False (1)
# motor send command 6 UI 24  False (1)
# motor send command 6 UF 1  True (2)
# motor send command 6 UF 2  True (2)
# motor send command 6 XM 1  False (1)
# motor send command 6 XM 2  False (1)
# motor send command 6 UF 3  True (2)
# motor send command 6 UF 4  True (2)
# motor send command 6 VH 3  False (1)
# motor send command 6 VL 3  False (1)
# motor send command 6 CA 45  False (1)
# motor send command 6 CA 41  False (1)
# motor send command 6 CA 46  False (1)
# motor send command 6 SP 2  False (1)
# motor send command 6 VH 2  False (1)
# motor send command 6 SD 0  False (1)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 6  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 7  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 8  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 9  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 10  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 11  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 12  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 13  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 14  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UF 15  True (2)
# node_id not int: 1 <enum 'KX2Axis'>
# motor send command 1 UI 17  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 6  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 7  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 8  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 9  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 10  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 11  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 12  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 13  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 14  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 15  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 16  True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 UF 17  True (2)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1719, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1591, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1591, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1591, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# motor send command 6 PL 1 0.9200000166893005 True (2)
# motor send command 6 CL 1 0.9100000262260437 True (2)
# ['100', '5000']
# (100,5000)
# XQ##Home(100,5000)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 PL 1 0.9200000166893005 True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1 0.9100000262260437 True (2)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 PL 1 0.9200000166893005 True (2)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 MS 1  False (1)
# Servo Gripper Motor Status: 0
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 IQ 0  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 IQ 0  False (1)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1719, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1719, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1719, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=1591, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5687, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.MotionStatusReceived: 2>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=True, msr_status_word=5815, mesr_status=0, dics_state=None, cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, True, False], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, True, True], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# EMCY received!!
# EventData(event_type=<EventType.CANEmergencyMessageReceived: 5>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=None, cemr_emcy_msg=Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0), cemr_description='E-stop button was pressed', cemr_disable_motors=True, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0)
# EMCY node=1 desc='E-stop button was pressed' disable_motors=True suppress_event=False
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, True, True, False, False, True, True], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, True, False], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, True, False], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# EMCY received!!
# EventData(event_type=<EventType.CANEmergencyMessageReceived: 5>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=None, cemr_emcy_msg=Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0), cemr_description='E-stop button was pressed', cemr_disable_motors=True, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0)
# EMCY node=2 desc='E-stop button was pressed' disable_motors=True suppress_event=False
# EMCY received!!
# EventData(event_type=<EventType.CANEmergencyMessageReceived: 5>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=None, cemr_emcy_msg=Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0), cemr_description='E-stop button was pressed', cemr_disable_motors=True, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0)
# EMCY node=3 desc='E-stop button was pressed' disable_motors=True suppress_event=False
# EMCY received!!
# EventData(event_type=<EventType.CANEmergencyMessageReceived: 5>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=None, cemr_emcy_msg=Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0), cemr_description='E-stop button was pressed', cemr_disable_motors=True, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0)
# EMCY node=4 desc='E-stop button was pressed' disable_motors=True suppress_event=False
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, True, True, True, False, True, True], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# EMCY received!!
# EventData(event_type=<EventType.CANEmergencyMessageReceived: 5>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=None, cemr_emcy_msg=Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0), cemr_description='E-stop button was pressed', cemr_disable_motors=True, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Emcy(err_code=21569, err_reg=33, elmo_err_code=0, err_code_data1=0, err_code_data2=0)
# EMCY node=6 desc='E-stop button was pressed' disable_motors=True suppress_event=False
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=1, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, False, False], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=2, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, True, True, False, False, False, True], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=3, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, False, False], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=4, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, False, False, False, False, False, False], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# Raising event: EventData(event_type=<EventType.DigitalInputChangedState: 4>, pending=False, node_id=6, cmr_msg_type='', cmr_data_type='', cmr_data='', mpc_position=None, msr_status=False, msr_status_word=0, mesr_status=0, dics_state=[False, True, True, True, False, False, True], cemr_emcy_msg=None, cemr_description='', cemr_disable_motors=False, me_error_code=0, me_index=0, mmd_all_moves_done=False)
# CAN Read Error: The value of a handle (PCAN-Channel, PCAN-Hardware, PCAN-Net, PCAN-Client) is invalid

# %%
await kx2.move_to_cartesian_position(
    GripperPose(
        location=Coordinate(x=-26.9701, y=160.9649, z=04.6119),
        rotation=Rotation(x=0, y=0, z=-171.05957734864037)
    ),
    vel_pct=20,
    accel_pct=20
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 await kx2.move_to_cartesian_position(
#       2     GripperPose(
#       3         location=Coordinate(x=-26.9701, y=160.9649, z=304.6119),
#       4         rotation=Rotation(x=0, y=0, z=-171.05957734864037)
#       5     ),
#       6     vel_pct=20,
#       7     accel_pct=20
#       8 )
#
# File ~/Desktop/GitHub/pylabrobot/pylabrobot/arms/kx2/kx2_backend.py:4062, in KX2Backend.move_to_cartesian_position(self, pose, vel_pct, accel_pct)
#    4055 async def move_to_cartesian_position(
#    4056   self,
#    4057   pose: GripperPose,
#    4058   vel_pct: float = 100,
#    4059   accel_pct: float = 100,
#    4060 ) -> None:
#    4061   joint_pos = self.convert_cartesian_to_joint_position(pose)
# -> 4062   await self.motors_move_joint(
#    4063     cmd_pos=joint_pos,
#    4064     cmd_vel_pct=vel_pct,
#    4065     cmd_accel_pct=accel_pct,
#    4066   )
#
# File ~/Desktop/GitHub/pylabrobot/pylabrobot/arms/kx2/kx2_backend.py:3907, in KX2Backend.motors_move_joint(self, cmd_pos, cmd_vel_pct, cmd_accel_pct)
#    3901 async def motors_move_joint(
#    3902   self,
#    3903   cmd_pos: Dict["KX2Axis", float],
#    3904   cmd_vel_pct: float,
#    3905   cmd_accel_pct: float,
#    3906 ) -> None:
# -> 3907   plan = await self.calculate_move_abs_all_axes(
#    3908     cmd_pos=cmd_pos,
#    3909     cmd_vel_pct=cmd_vel_pct,
#    3910     cmd_accel_pct=cmd_accel_pct,
#    3911   )
#    3913   if plan is None:  # if every axis is skipped, exit
#    3914     return
#
# File ~/Desktop/GitHub/pylabrobot/pylabrobot/arms/kx2/kx2_backend.py:3760, in KX2Backend.calculate_move_abs_all_axes(self, cmd_pos, cmd_vel_pct, cmd_accel_pct)
#    3758       target[ax] = low
#    3759     else:
# -> 3760       raise ValueError(f"Axis {ax!r} below min travel")
#    3762 # Clearance check
#    3763 if KX2Axis.Z in axes:
#
# ValueError: Axis <KX2Axis.ELBOW: 3> below min travel

# %%
await kx2.servo_gripper_open(open_position=25.0)

# %%
await kx2.activate_free_mode()

# %%
await kx2.deactivate_free_mode()

# %%
await kx2.servo_gripper_open(open_position=10.0)

# %%
home_position =  await kx2.get_cartesian_position()

home_position
# Out:
# GripperPose(location=Coordinate(x=-26.9701, y=160.9649, z=704.6119), rotation=Rotation(x=0, y=0, z=-171.05957734864037))

# %%
byonoy_dector_unit_location = await kx2.get_cartesian_position()
byonoy_dector_unit_location
# Out:
# GripperPose(location=Coordinate(x=-195.1244, y=518.7307, z=37.6328), rotation=Rotation(x=0, y=0, z=-161.802826074163))

# %%
byonoy_dector_unit_location = GripperPose(location=Coordinate(x=-195.1244, y=518.7307, z=37.6328), rotation=Rotation(x=0, y=0, z=-161.802826074163))

# %%
waypoint_z_0 = GripperPose(location=Coordinate(x=-195.1244, y=518.7307, z=37.6328 + 100), rotation=Rotation(x=0, y=0, z=-161.802826074163))

# %%
await kx2.move_to_cartesian_position(
    waypoint_z_0,
    vel_pct=20,
    accel_pct=20
)

# %%
await kx2.move_to_cartesian_position(
    byonoy_dector_unit_location,
    vel_pct=20,
    accel_pct=20
)

# %%
kx2.servo_gripper_closed_position = 8
await kx2.servo_gripper_close()
# Out:
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 MS 1  False (1)
# Servo Gripper Motor Status: 1
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 IQ 0  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 IQ 0  False (1)

# %%
gp = GripperPose(location=Coordinate(x=222.8748, y=185.6677, z=520.8049), rotation=Rotation(x=0, y=0, z=-122.82045997896907))
await kx2.move_to_cartesian_position(gp, vel_pct=20, accel_pct=20)

# %%
drawer4 = GripperPose(location=Coordinate(x=101.001, y=296.6519, z=73.1333 + 47), rotation=Rotation(x=0, y=0, z=271.01718397191803))
await kx2.move_to_cartesian_position(drawer4, vel_pct=10, accel_pct=10)
# Out:
# convert_elbow_angle_to_position: 14.987054443359375 -> 161.7143894118624
# MotorMoveParam(axis=<Axis.SHOULDER: 1>, position=7950488, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# MotorMoveParam(axis=<Axis.Z: 2>, position=480273, velocity=299838, acceleration=399784, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.ELBOW: 3>, position=272840, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.WRIST: 4>, position=13190, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# motor_wait_for_move_done 4147.999458000006
# motor_wait_for_move_done 3986.5379170000087
# motor_wait_for_move_done 1000
# motor_wait_for_move_done 1000

# %%
top = GripperPose(location=Coordinate(x=101.001, y=296.6519, z=300), rotation=Rotation(x=0, y=0, z=271.01718397191803))
await kx2.move_to_cartesian_position(top)
# Out:
# convert_elbow_angle_to_position: 14.987548828125 -> 161.718473622052
# MotorMoveParam(axis=<Axis.SHOULDER: 1>, position=7950488, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# MotorMoveParam(axis=<Axis.Z: 2>, position=1199351, velocity=1695512, acceleration=3997842, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.ELBOW: 3>, position=272840, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.WRIST: 4>, position=13190, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# motor_wait_for_move_done 1847.9994579999911
# motor_wait_for_move_done 1746.921291999999
# motor_wait_for_move_done 1000
# motor_wait_for_move_done 1000

# %%
await scila.open_drawer(4)

# %%
await kx2.move_to_cartesian_position(drawer4, vel_pct=10, accel_pct=10)
# Out:
# convert_elbow_angle_to_position: 14.987548828125 -> 161.718473622052
# MotorMoveParam(axis=<Axis.SHOULDER: 1>, position=7950488, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# MotorMoveParam(axis=<Axis.Z: 2>, position=480273, velocity=299838, acceleration=399784, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.ELBOW: 3>, position=272840, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.WRIST: 4>, position=13190, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# motor_wait_for_move_done 4147.999542000005
# motor_wait_for_move_done 4047.0339999999997
# motor_wait_for_move_done 1000
# motor_wait_for_move_done 1000

# %%
await kx2.servo_gripper_close()
# Out:
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 MS 1  False (1)
# Servo Gripper Motor Status: 0
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 IQ 0  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 CL 1  False (1)
# node_id not int: 6 <enum 'KX2Axis'>
# motor send command 6 IQ 0  False (1)

# %%
await kx2.move_to_cartesian_position(top, vel_pct=10, accel_pct=10)
# Out:
# convert_elbow_angle_to_position: 14.987548828125 -> 161.718473622052
# MotorMoveParam(axis=<Axis.SHOULDER: 1>, position=7950488, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# MotorMoveParam(axis=<Axis.Z: 2>, position=1199351, velocity=299838, acceleration=399784, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.ELBOW: 3>, position=272840, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.WRIST: 4>, position=13190, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# motor_wait_for_move_done 4147.999582999997
# motor_wait_for_move_done 4046.764290999985
# motor_wait_for_move_done 1000
# motor_wait_for_move_done 1000

# %%
await scila.close_drawer(4)
# Out:
# No pending command to match response to.
# No pending command to match response to.

# %%
await scila.open_drawer(3)

# %%
drawer3 = GripperPose(location=Coordinate(x=101.001, y=296.6519, z=73.1333), rotation=Rotation(x=0, y=0, z=271.01718397191803))
await kx2.move_to_cartesian_position(drawer3, vel_pct=10, accel_pct=10)
# Out:
# convert_elbow_angle_to_position: 14.987548828125 -> 161.718473622052
# MotorMoveParam(axis=<Axis.SHOULDER: 1>, position=7950488, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# MotorMoveParam(axis=<Axis.Z: 2>, position=292375, velocity=299838, acceleration=399784, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.ELBOW: 3>, position=272840, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.WRIST: 4>, position=13190, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# motor_wait_for_move_done 4774.999332999985
# motor_wait_for_move_done 4673.443916000018
# motor_wait_for_move_done 1000
# motor_wait_for_move_done 1000

# %%
await kx2.servo_gripper_open()
# Out:
# convert_elbow_angle_to_position: 14.987548828125 -> 161.718473622052
# MotorMoveParam(axis=<Axis.SERVO_GRIPPER: 6>, position=79577, velocity=77970, acceleration=636620, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# motor_wait_for_move_done 1244.9996249999967

# %%
await kx2.move_to_cartesian_position(top, vel_pct=10, accel_pct=10)
# Out:
# convert_elbow_angle_to_position: 14.987548828125 -> 161.718473622052
# MotorMoveParam(axis=<Axis.SHOULDER: 1>, position=7950488, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# MotorMoveParam(axis=<Axis.Z: 2>, position=1199351, velocity=299838, acceleration=399784, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.ELBOW: 3>, position=272840, velocity=1000, acceleration=1000, relative=False, direction=<eJointMoveDirection.Normal: 0>)
# MotorMoveParam(axis=<Axis.WRIST: 4>, position=13190, velocity=1, acceleration=3, relative=False, direction=<eJointMoveDirection.ShortestWay: 3>)
# motor_wait_for_move_done 4774.999125000031
# motor_wait_for_move_done 4673.237708000001
# motor_wait_for_move_done 1000
# motor_wait_for_move_done 1000

# %%
await scila.close_drawer(3)
